# %% [markdown]
# # STOCK SENTIMENT ANALYSIS

# %% [markdown]
# This project is about predecting if the stock price would increse or decrease depending upon the news headline.
# The data set is from Kaggle - https://www.kaggle.com/aaron7sun/stocknews?select=Combined_News_DJIA.csv

# %% [markdown]
# In this project I would be using Word Embedding Techniques -
#
# 1. Count Vectorizer
# 2. Tf-idf
#
# I would also be using Machine learning models-
#
# 1. Random Forest Classifier
# 2. Naive Bayes
# 3. XGBoost

# %% [markdown]
# #### DATASET :

# %% [markdown]
# The dataset set consists date from Aug 2008 to July 2016, Label which depicts increase(1) or decrease(0) in prices,Top 10 headlines in 10 different column

# %%
import pandas as pd
import numpy as np 
import re

df= pd.read_csv('Top Headlines.csv', encoding = "ISO-8859-1")
df.head(2)
# Out:
#          Date  Label                                               Top1  \
# 0  2008-08-08      0  b"Georgia 'downs two Russian warplanes' as cou...
# 1  2008-08-11      1  b'Why wont America and Nato help us? If they w...
#
#                                           Top2  \
# 0      b'BREAKING: Musharraf to be impeached.'
# 1  b'Bush puts foot down on Georgian conflict'
#
#                                                 Top3  \
# 0  b'Russia Today: Columns of troops roll into So...
# 1  b"Jewish Georgian minister: Thanks to Israeli ...
#
#                                                 Top4  \
# 0  b'Russian tanks are moving towards the capital...
# 1  b'Georgian army flees in disarray as Russians ...
#
#                                                 Top5  \
# 0  b"Afghan children raped with 'impunity,' U.N. ...
# 1      b"Olympic opening ceremony fireworks 'faked'"
#
#                                                 Top6  \
# ...

# %%
#Make sure that the date is sorted
df = df.sort_values('Date')
df
# Out:
#             Date  Label                                               Top1  \
# 0     2008-08-08      0  b"Georgia 'downs two Russian warplanes' as cou...
# 1     2008-08-11      1  b'Why wont America and Nato help us? If they w...
# 2     2008-08-12      0  b'Remember that adorable 9-year-old who sang a...
# 3     2008-08-13      0  b' U.S. refuses Israel weapons to attack Iran:...
# 4     2008-08-14      1  b'All the experts admit that we should legalis...
# ...          ...    ...                                                ...
# 1984  2016-06-27      0  Barclays and RBS shares suspended from trading...
# 1985  2016-06-28      1  2,500 Scientists To Australia: If You Want To ...
# 1986  2016-06-29      1                   Explosion At Airport In Istanbul
# 1987  2016-06-30      1  Jamaica proposes marijuana dispensers for tour...
# 1988  2016-07-01      1  A 117-year-old woman in Mexico City finally re...
#
#                                                    Top2  \
# ...

# %%
#Since its a time series we cannot split the data randomly as each date has dependencies over previous dates
#train_set, test_set= np.split(df, [int(.75 *len(df))])
train_set = df[df['Date'] < '20150101']
test_set = df[df['Date'] > '20141231']

# %%
#check if it has actaully split without randomness
train_set.head()
#test_set.tail()
# Out:
#          Date  Label                                               Top1  \
# 0  2008-08-08      0  b"Georgia 'downs two Russian warplanes' as cou...
# 1  2008-08-11      1  b'Why wont America and Nato help us? If they w...
# 2  2008-08-12      0  b'Remember that adorable 9-year-old who sang a...
# 3  2008-08-13      0  b' U.S. refuses Israel weapons to attack Iran:...
# 4  2008-08-14      1  b'All the experts admit that we should legalis...
#
#                                                 Top2  \
# 0            b'BREAKING: Musharraf to be impeached.'
# 1        b'Bush puts foot down on Georgian conflict'
# 2                 b"Russia 'ends Georgia operation'"
# 3  b"When the president ordered to attack Tskhinv...
# 4  b'War in South Osetia - 89 pictures made by a ...
#
#                                                 Top3  \
# 0  b'Russia Today: Columns of troops roll into So...
# 1  b"Jewish Georgian minister: Thanks to Israeli ...
# ...

# %%
# Removing punctuations
data=train_set.iloc[:,2:27]
data.replace("[^a-zA-Z]"," ",regex=True, inplace=True)
data.head(2)
# Out:
#                                                 Top1  \
# 0  b Georgia  downs two Russian warplanes  as cou...
# 1  b Why wont America and Nato help us  If they w...
#
#                                           Top2  \
# 0      b BREAKING  Musharraf to be impeached
# 1  b Bush puts foot down on Georgian conflict
#
#                                                 Top3  \
# 0  b Russia Today  Columns of troops roll into So...
# 1  b Jewish Georgian minister  Thanks to Israeli ...
#
#                                                 Top4  \
# 0  b Russian tanks are moving towards the capital...
# 1  b Georgian army flees in disarray as Russians ...
#
#                                                 Top5  \
# 0  b Afghan children raped with  impunity   U N  ...
# 1      b Olympic opening ceremony fireworks  faked
#
#                                                 Top6  \
# 0  b     Russian tanks have entered South Ossetia...
# 1  b What were the Mossad with fraudulent New Zea...
#
# ...

# %%
# Renaming column names for ease of access
list1= [i for i in range(len(data.columns))]
new_Index=[str(i) for i in list1]
data.columns= new_Index
data.head(2)
# Out:
#                                                    0  \
# 0  b Georgia  downs two Russian warplanes  as cou...
# 1  b Why wont America and Nato help us  If they w...
#
#                                              1  \
# 0      b BREAKING  Musharraf to be impeached
# 1  b Bush puts foot down on Georgian conflict
#
#                                                    2  \
# 0  b Russia Today  Columns of troops roll into So...
# 1  b Jewish Georgian minister  Thanks to Israeli ...
#
#                                                    3  \
# 0  b Russian tanks are moving towards the capital...
# 1  b Georgian army flees in disarray as Russians ...
#
#                                                    4  \
# 0  b Afghan children raped with  impunity   U N  ...
# 1      b Olympic opening ceremony fireworks  faked
#
#                                                    5  \
# 0  b     Russian tanks have entered South Ossetia...
# 1  b What were the Mossad with fraudulent New Zea...
#
# ...

# %%
# Convertng headlines to lower case
for index in new_Index:
    data[index]=data[index].str.lower()
data.head(1)
# Out:
#                                                    0  \
# 0  b georgia  downs two russian warplanes  as cou...
#
#                                          1  \
# 0  b breaking  musharraf to be impeached
#
#                                                    2  \
# 0  b russia today  columns of troops roll into so...
#
#                                                    3  \
# 0  b russian tanks are moving towards the capital...
#
#                                                    4  \
# 0  b afghan children raped with  impunity   u n  ...
#
#                                                    5  \
# 0  b     russian tanks have entered south ossetia...
#
#                                                    6  \
# 0  b breaking  georgia invades south ossetia  rus...
#
#                                                    7  \
# 0  b the  enemy combatent  trials are nothing but...
#
#                                                    8  \
# ...

# %%
#combine a whole row and see the result. We need to do it for all the rows.
headline_row_1=' '.join(str(x) for x in data.iloc[0,0:25])
headline_row_1
# Out:
# 'b georgia  downs two russian warplanes  as countries move to brink of war  b breaking  musharraf to be impeached   b russia today  columns of troops roll into south ossetia  footage from fighting  youtube   b russian tanks are moving towards the capital of south ossetia  which has reportedly been completely destroyed by georgian artillery fire  b afghan children raped with  impunity   u n  official says   this is sick  a three year old was raped and they do nothing  b     russian tanks have entered south ossetia whilst georgia shoots down two russian jets   b breaking  georgia invades south ossetia  russia warned it would intervene on so s side  b the  enemy combatent  trials are nothing but a sham  salim haman has been sentenced to       years  but will be kept longer anyway just because they feel like it   b georgian troops retreat from s  osettain capital  presumably leaving several hundred people killed   video   b did the u s  prep georgia for war with russia   b rice gives gre
# ...

# %%
#we can see that letter 'b' is useless. The follwoing code would eleiminate all the single letters from the headlines
headline_row_1 = re.sub(r"\b[a-zA-Z]\b", "", headline_row_1)
headline_row_1
# Out:
# ' georgia  downs two russian warplanes  as countries move to brink of war   breaking  musharraf to be impeached    russia today  columns of troops roll into south ossetia  footage from fighting  youtube    russian tanks are moving towards the capital of south ossetia  which has reportedly been completely destroyed by georgian artillery fire   afghan children raped with  impunity      official says   this is sick   three year old was raped and they do nothing       russian tanks have entered south ossetia whilst georgia shoots down two russian jets    breaking  georgia invades south ossetia  russia warned it would intervene on so  side   the  enemy combatent  trials are nothing but  sham  salim haman has been sentenced to       years  but will be kept longer anyway just because they feel like it    georgian troops retreat from   osettain capital  presumably leaving several hundred people killed   video    did the    prep georgia for war with russia    rice gives green light for israel
# ...

# %%
#Lets work it out for all the rows(dates)
headlines = []
for row in range(0,len(data.index)):
    headlines.append(re.sub(r"\b[a-zA-Z]\b", "", ' '.join(str(x) for x in data.iloc[row,0:25])))

# %%
headlines[0]
# Out:
# ' georgia  downs two russian warplanes  as countries move to brink of war   breaking  musharraf to be impeached    russia today  columns of troops roll into south ossetia  footage from fighting  youtube    russian tanks are moving towards the capital of south ossetia  which has reportedly been completely destroyed by georgian artillery fire   afghan children raped with  impunity      official says   this is sick   three year old was raped and they do nothing       russian tanks have entered south ossetia whilst georgia shoots down two russian jets    breaking  georgia invades south ossetia  russia warned it would intervene on so  side   the  enemy combatent  trials are nothing but  sham  salim haman has been sentenced to       years  but will be kept longer anyway just because they feel like it    georgian troops retreat from   osettain capital  presumably leaving several hundred people killed   video    did the    prep georgia for war with russia    rice gives green light for israel
# ...

# %% [markdown]
# ### FEATURE EXTRACTION AND MODELLING

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
import xgboost as xgb
from xgboost import XGBClassifier

# %% [markdown]
# There are differegt types of Encoders that we can use. Here I am using
# 1. Count Vectorizer (One Hot Encoding)
# 2. TF-IDF

# %% [markdown]
# #### COUNT VECTOR

# %%
## implement BAG OF WORDS
countvector=CountVectorizer(ngram_range=(2,2))
traindataset=countvector.fit_transform(headlines) #traindataset would be a sparse matrix

# I didnt allow the preprocessing of test as it wont help me to predict really word data down the line
## Predict for the Test Dataset
test_transform= []
for row in range(0,len(test_set.index)):
    test_transform.append(' '.join(str(x) for x in test_set.iloc[row,2:27]))
test_dataset = countvector.transform(test_transform)

# %%
def models(traindataset,test_dataset):
    
    # implement RandomForest Classifier
    randomclassifier=RandomForestClassifier(n_estimators=200,criterion='entropy')
    randomclassifier.fit(traindataset,train_set['Label'])
    predictions_random = randomclassifier.predict(test_dataset)
    
    #implement MultinomialNB Classifier
    #naive bias - Gaussian NB(cannot have input as matrix. Send as array insted of matrix),
    # Hence use Multinomial NB (use when matrix is input)
    naive = MultinomialNB()
    naive.fit(traindataset,train_set['Label'])
    predictions_naive = naive.predict(test_dataset)

    # implement XgBoost Classifier
    XgBoost = XGBClassifier(max_depth=2, n_estimators=30)
    XgBoost.fit(traindataset,train_set['Label'])
    predictions_xgboost = XgBoost.predict(test_dataset)
    
    return (predictions_random,predictions_naive,predictions_xgboost)

# %%
## Import library to check accuracy
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

def PerformanceReport(random,naive,xgboost):
    print("RandomForest:")
    matrix=confusion_matrix(test_set['Label'],random)
    print(matrix)
    score=accuracy_score(test_set['Label'],random)
    print(score)
    report=classification_report(test_set['Label'],random)
    print(report)

    print("NaiveBayes:")
    matrix=confusion_matrix(test_set['Label'],naive)
    print(matrix)
    score=accuracy_score(test_set['Label'],naive)
    print(score)
    report=classification_report(test_set['Label'],naive)
    print(report)

    print("XgBoost:")
    matrix=confusion_matrix(test_set['Label'],xgboost)
    print(matrix)
    score=accuracy_score(test_set['Label'],xgboost)
    print(score)
    report=classification_report(test_set['Label'],xgboost)
    print(report)

# %%
#feed to models and get the predicted values. Just for the sake of simplicity i am using few models
random,naive,xgboost = models(traindataset,test_dataset)


#Performance Report
print("Performance Report for CountVector:")
PerformanceReport(random,naive,xgboost)
# Out:
# Performance Report for CountVector:
# RandomForest:
# [[133  53]
#  [  3 189]]
# 0.8518518518518519
#               precision    recall  f1-score   support
#
#            0       0.98      0.72      0.83       186
#            1       0.78      0.98      0.87       192
#
#     accuracy                           0.85       378
#    macro avg       0.88      0.85      0.85       378
# weighted avg       0.88      0.85      0.85       378
#
# NaiveBayes:
# [[140  46]
#  [ 12 180]]
# 0.8465608465608465
#               precision    recall  f1-score   support
#
#            0       0.92      0.75      0.83       186
#            1       0.80      0.94      0.86       192
#
#     accuracy                           0.85       378
#    macro avg       0.86      0.85      0.84       378
# weighted avg       0.86      0.85      0.85       378
#
# XgBoost:
# [[ 40 146]
#  [ 11 181]]
# 0.5846560846560847
#               precision    recall  f1-score   support
#
# ...

# %% [markdown]
# #### TF - IDF

# %%
## implement BAG OF WORDS
Tfidfvector=TfidfVectorizer(ngram_range=(2,2))
traindataset=Tfidfvector.fit_transform(headlines) #traindataset would be a sparse matrix

# I didnt allow the preprocessing of test as it wont help me to predict really word data down the line
## Predict for the Test Dataset
test_transform= []
for row in range(0,len(test_set.index)):
    test_transform.append(' '.join(str(x) for x in test_set.iloc[row,2:27]))
test_dataset = Tfidfvector.transform(test_transform)

# %%
#feed to model
random,naive,xgboost = models(traindataset,test_dataset)

#Performance Report
print("Performance Report for Tf-idf:")
PerformanceReport(random,naive,xgboost)
# Out:
# Performance Report for Tf-idf:
# RandomForest:
# [[147  39]
#  [ 18 174]]
# 0.8492063492063492
#               precision    recall  f1-score   support
#
#            0       0.89      0.79      0.84       186
#            1       0.82      0.91      0.86       192
#
#     accuracy                           0.85       378
#    macro avg       0.85      0.85      0.85       378
# weighted avg       0.85      0.85      0.85       378
#
# NaiveBayes:
# [[130  56]
#  [  0 192]]
# 0.8518518518518519
#               precision    recall  f1-score   support
#
#            0       1.00      0.70      0.82       186
#            1       0.77      1.00      0.87       192
#
#     accuracy                           0.85       378
#    macro avg       0.89      0.85      0.85       378
# weighted avg       0.89      0.85      0.85       378
#
# XgBoost:
# [[ 47 139]
#  [  7 185]]
# 0.6137566137566137
#               precision    recall  f1-score   support
#
# ...

# %% [markdown]
# #### HYPERPARAMETER TUNING

# %% [markdown]
# Lets try to improve the performance of Random forest Classfier using Grid Search Cross Validation. For that we need to know the current values of parameters.

# %%
randomclassifier.fit(traindataset,train_set['Label'])
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %% [markdown]
# Since we have good accuracy, we can see just vary the parameters closely. For example, we have min_samples_split=2, lets test with 1,2,3. also due to no GPU I am just adding only 1-2 extra value.

# %% [markdown]
# I am using the countvector dataset because it has the Randomforest as best classifier. We can also change the variable name traindatasetCV, test_datasetCV. However, I am just copy pasting for simplicity

# %%
## implement BAG OF WORDS
countvector=CountVectorizer(ngram_range=(2,2))
traindataset=countvector.fit_transform(headlines) #traindataset would be a sparse matrix

# I didnt allow the preprocessing of test as it wont help me to predict really word data down the line
## Predict for the Test Dataset
test_transform= []
for row in range(0,len(test_set.index)):
    test_transform.append(' '.join(str(x) for x in test_set.iloc[row,2:27]))
test_dataset = countvector.transform(test_transform)

# %%
from sklearn.model_selection import GridSearchCV
# Create the parameter grid based on the results of random search 
param_grid = {
    'min_samples_leaf': [1,2,3],
    'min_samples_split': [1,2,3],
    'n_estimators': [190,200,210] 
}
# Create a based model
rf = RandomForestClassifier()
# Instantiate the grid search model
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 3, n_jobs = -1, verbose = 2)

# %%
# Fit the grid search to the data
grid_search.fit(traindataset,train_set['Label'])
grid_search.best_params_
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done  81 out of  81 | elapsed:  5.7min finished
# {'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}

# %%
best_grid = grid_search.best_estimator_

predictions = best_grid.predict(test_dataset)

print("Performance report:")
matrix=confusion_matrix(test_set['Label'],predictions)
print(matrix)
score=accuracy_score(test_set['Label'],predictions)
print(score)
report=classification_report(test_set['Label'],predictions)
print(report)
# Out:
# Performance report:
# [[131  55]
#  [  2 190]]
# 0.8492063492063492
#               precision    recall  f1-score   support
#
#            0       0.98      0.70      0.82       186
#            1       0.78      0.99      0.87       192
#
#     accuracy                           0.85       378
#    macro avg       0.88      0.85      0.85       378
# weighted avg       0.88      0.85      0.85       378

# %% [markdown]
# the performance didnt change much and is slightly decreased. I would choose the other model without hyper parameter tuning as F1 scores are same in both cases.
#
# #### Hence the best model is Random forest with countvectorizer embedding

# %% [markdown]
# #### NOTE:-
#
# If you are working with basic NLP techniques like BOW, Count Vectorizer or TF-IDF(Term Frequency and Inverse Document Frequency) then removing stopwords is a good idea because stopwords act like noise for these methods. If you working with LSTM’s or other models which capture the semantic meaning and the meaning of a word depends on the context of the previous text, then it becomes important not to remove stopwords.
#
#
# Also for reviews like
#
# "I dont like this product" - Negative. If we remove stopwords, it becomes "Like project"- Positive. Hence It always better to use LSTM in as many cases as possible
#
# Refer - https://towardsdatascience.com/why-you-should-avoid-removing-stopwords-aa7a353d2a52

# %% [markdown]
# #### REFERENCE:-
# 1. Krish Naik You tube channel - https://www.youtube.com/channel/UCNU_lfiiWBdtULKOw6X0Dig
# 2. Cleared minor doubts from Stackoverflow https://stackoverflow.com/
